# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
from sklearn.decomposition import PCA

import datasci

# %% [markdown]
# # Data

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# # scikit-learn

# %%
plt.scatter(*PCA(n_components=2).fit_transform(X).T)
plt.show()

# %% [markdown]
# # CodeMedley

# %%
plt.scatter(*datasci.dim_red_2D(X).T)
plt.show()
